# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Distributed plot

sns.distplot(x=df['age'],bins=10)
# Out:
# C:\Users\jayba\AppData\Local\Temp\ipykernel_18944\2388288210.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['age'],bins=10)
# <Axes: ylabel='Density'>

# %%
# Histogram
sns.histplot(x=df['age'],bins=10,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# Joint PLot & Bar Plot
# plot 1
sns.jointplot(x=df['age'],y=df['fare'],kind='scatter')

# %%
# plot 2
sns.jointplot(x=df['age'],y=df['fare'],kind='hex')

# %%
# bar plot
sns.barplot(x=df['sex'],y=df['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x=df['sex'],y=df['age'],estimator=np.std)
# Out:
# C:\Users\jayba\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# C:\Users\jayba\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# <Axes: xlabel='sex', ylabel='age'>

# %%
# count plot
sns.countplot(x=df['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# box plot
sns.boxplot(x=df['sex'],y=df['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x=df['sex'],y=df['age'],hue=df['alive'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# violin plot
sns.violinplot(x=df['sex'],y=df['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x=df['sex'],y=df['age'],hue=df['alive'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# strip plot
sns.stripplot(x=df['sex'],y=df['age'],jitter=True,hue=df['alive'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x=df['sex'],y=df['age'],jitter=False,hue=df['alive'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# the swarm plot
sns.swarmplot(x=df['sex'],y=df['age'],hue=df['alive'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# heat map
corr=df.corr()
corr
# Out:
# C:\Users\jayba\AppData\Local\Temp\ipykernel_18944\618994018.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
# Hist plot
sns.histplot(df['fare'],bins=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>
